# %%
anno="2026"
print(type(anno))
# Out:
# <class 'str'>

# %%
print('Hola Mundo')
# Out:
# Hola Mundo

# %%
nombre="Matilda"
año="1996"
visto=True
print(f"La película {nombre},fue estrenada en el año {año}, ¿es famosa esta película? {visto} ")
# Out:
# La película Matilda,fue estrenada en el año 1996, ¿es famosa esta película? True

# %%
peliculas=[
    "The Shawshank Redemption",
    "The Dark Knight",
    "Inception",
    "Pulp Fiction",
    "The Matrix",
    "Interstellar",
    "Parasite",
    "Gladiator",
    "Titanic",
    "The Lord of the Rings: The Fellowship of the Ring"
]


anios=[
    1994,
    2008,
    2010,
    1994,
    1999,
    2014,
    2019,
    2000,
    1997,
    2001
]


exito=[
    True,
    False,
    True,
    False,
    True,
    False,
    True,
    False,
    True,
    False
]

for pelicula, anio, fue_exito in zip(peliculas, anios, exito):
    resultado = "Sí" if fue_exito else "No"
    print(f"La película '{pelicula}' se estrenó en {anio}. ¿Alcanzó el éxito? {resultado}")
# Out:
# La película 'The Shawshank Redemption' se estrenó en 1994. ¿Alcanzó el éxito? Sí
# La película 'The Dark Knight' se estrenó en 2008. ¿Alcanzó el éxito? No
# La película 'Inception' se estrenó en 2010. ¿Alcanzó el éxito? Sí
# La película 'Pulp Fiction' se estrenó en 1994. ¿Alcanzó el éxito? No
# La película 'The Matrix' se estrenó en 1999. ¿Alcanzó el éxito? Sí
# La película 'Interstellar' se estrenó en 2014. ¿Alcanzó el éxito? No
# La película 'Parasite' se estrenó en 2019. ¿Alcanzó el éxito? Sí
# La película 'Gladiator' se estrenó en 2000. ¿Alcanzó el éxito? No
# La película 'Titanic' se estrenó en 1997. ¿Alcanzó el éxito? Sí
# La película 'The Lord of the Rings: The Fellowship of the Ring' se estrenó en 2001. ¿Alcanzó el éxito? No
